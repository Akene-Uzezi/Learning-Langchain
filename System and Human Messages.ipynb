# %%
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
import os

# %%
load_dotenv()
# Out:
# True

# %%
apiKey = os.environ.get("OPENROUTER_API_KEY")

# %%
model = os.environ.get("modelName")

# %%
chat = ChatOpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=apiKey,
    model=model,
    model_kwargs= {'seed': 365},
    temperature = 0,
    max_completion_tokens=100
)
# Out:
# /home/emperor/anaconda3/envs/langchainEnv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3517: UserWarning: Parameters {'seed'} should be specified explicitly. Instead they were passed in as part of `model_kwargs` parameter.
#   if await self.run_code(code, result, async_=asy):

# %%
messageHDog = HumanMessage(content='''Ive adopted a dog. Suggest dog names''')
messageAiDog = AIMessage(content=''' Oh, absolutely. Because nothing screams "I'm a responsible pet owner" 
like asking a chatbot to name your new furball. How about "Bark Twain" (if it's a literary hound)?''')
messageHCat = HumanMessage(content='''Ive recently adopted a cat. Suggest cat names''')
messageAiCat = AIMessage(content='''Oh, absolutely. Because nothing screams "I'm a unique and creative individual" 
like asking a chatbot to name your cat. How about "Furry McFurFace", "Sir Meowsalot", or "Catastrophe"?''')
messageHFish = HumanMessage(content='''Ive adopted a fish. suggest fish names''')

# %%
response = chat.invoke([messageHDog, messageAiDog, messageHCat, messageAiCat, messageHFish])

# %%
print(response.content)
# Out:
# Congratulations on the new fin‑tastic addition to your family! Here are a variety of fish‑friendly names to suit different personalities, colors, and species. Feel free to mix and match or tweak them to fit your aquatic buddy perfectly.
#
# ---
#
# ## Classic & Cute
#
# | Name | Why It Works |
# |------|--------------|
# | Bubbles | Perfect for a lively, active swimmer |
# | Finley | A playful nod to those beautiful fins |
# | Goldie | Ideal for goldfish or any golden‑hued swimmer |
# | Coral | Great for a reef‑loving or brightly colored fish |
# | Splash | Fun for a fish that loves to dart around |
#
# ---
#
# ## Elegant & Sophisticated
#
# | Name | Why It Works |
# |------|--------------|
# | Aurora | Evokes the shimmering colors of a tropical fish |
# | Marlin | Strong, sleek, and a nod to the ocean’s great hunters |
# | Selene | Moon‑lit elegance, great for a silvery or pale fish |
# | Zephyr | Light, breezy, perfect for a graceful swimmer |
# | Opal | Reflective, iridescent, ideal for a fish with a pearly sheen |
#
# ---
#
# ## Whimsical & Fun
#
# | Name | Why It Works |
# |------|--------------|
# | Sir Swims‑a‑Lot | A regal title for a fish that’s always on the move |
# | Nemo‑ette | A cute twist on the famous clownfish |
# | Sushi | Playful and food‑related—just don’t feed it sushi! |
# | Wavy McWaveface | A tongue‑in‑cheek nod to internet culture |
# | Glitterfin | Perfect for a fish with sparkling scales |
#
# ---
#
# ## Nature‑Inspired
#
# | Name | Why It Works |
# |------|--------------|
# | River | Great for a freshwater species |
# | Tide | Works well for a marine or brackish fish |
# | Pebble | Cute for a small, rounded fish |
# | Willow | Soft and gentle, ideal for a calm swimmer |
# | Storm | Strong, dynamic, perfect for a bold, fast fish |
#
# ---
#
# ## Mythical & Fantasy
#
# | Name | Why It Works |
# |------|--------------|
# | Triton | The sea god’s name fits a regal fish |
# | Nixie | A water sprite from folklore |
# | Leviathan | For a larger, impressive fish |
# | Selkie | A mythical seal‑person, great for a sleek swimmer |
# | Siren | Enchanting and melodic, perfect for a beautiful fish |
#
# ---
#
# ## Short & Sweet (One‑Word Options)
#
# - **Aqua**
# - **Jade**
# - **Pixel**
# - **Mako**
# - **Luna**
# - **Zara**
# - **Koi**
# - **Basil**
# - **Echo**
# - **Rex**
#
# ---
#
# ### How to Choose the Perfect Name
#
# 1. **Observe Their Personality** – Is your fish shy, bold, curious, or lazy? A name like “Dash” fits a speedy swimmer, while “Zen” suits a calm, gliding fish.
# 2. **Consider Color & Pattern** – Bright orange? “Tangerine.” Striped? “Zebra.” Iridescent? “Prism.”
# 3. **Think About Length** – Short names are easier for you to say and for the fish (if you ever try to train it to respond to sound cues!).
# 4. **Test It Out** – Say the name aloud a few times. Does it feel right? Does it make you smile?
#
# ---
#
# **Final Thought:** Whatever you pick, the name will become part of the bond you share with your new aquatic companion. Have fun naming, and enjoy watching your fish explore its new home! 🐠✨
